# %%
import pandas as pd
import matplotlib.pyplot as plt

pumpkins = pd.read_csv('../data/US-pumpkins.csv')
pumpkins.head()
pumpkins = pumpkins[pumpkins['Package'].str.contains('bushel', case=True, regex=True)]

pumpkins.isnull().sum()

new_columns = ['Color', 'Date']
pumpkins = pumpkins.drop([c for c in pumpkins.columns if c not in new_columns], axis=1)
print(pumpkins)
print(pumpkins['Color'])

# month = pd.DatetimeIndex(pumpkins['Date']).month

# new_pumpkins = pd.DataFrame({'Color': pumpkins['Color'], 'Date': pumpkins['Date']})
# new_pumpkins.loc[new_pumpkins['Package'].str.contains('1 1/9'), 'Price'] = price/(1 + 1/9)

# new_pumpkins.loc[new_pumpkins['Package'].str.contains('1/2'), 'Price'] = price/(1/2)

new_pumpkins.groupby(['Color']).plot(kind='bar')
# plt.ylabel("Pumpkin Price")
# Out:
#          Date   Color
# 70    9/24/16  ORANGE
# 71    9/24/16  ORANGE
# 72    10/1/16  ORANGE
# 73    10/1/16  ORANGE
# 74    10/8/16  ORANGE
# ...       ...     ...
# 1738  9/30/16   WHITE
# 1739  9/30/16   WHITE
# 1740  9/30/16  ORANGE
# 1741  9/30/16   WHITE
# 1742  9/30/16  ORANGE
#
# [415 rows x 2 columns]
# 70      ORANGE
# 71      ORANGE
# 72      ORANGE
# 73      ORANGE
# 74      ORANGE
#          ...
# 1738     WHITE
# 1739     WHITE
# 1740    ORANGE
# 1741     WHITE
# 1742    ORANGE
# Name: Color, Length: 415, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     893             try:
# --> 894                 result = self._python_apply_general(f, self._selected_obj)
#     895             except TypeError:
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     237             group_axes = group.axes
# --> 238             res = f(group)
#     239             if not _is_indexed_like(res, group_axes, axis):
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\groupby\groupby.py in f(self)
#     462         def f(self):
# --> 463             return self.plot(*args, **kwargs)
#     464
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     277         self._args_adjust()
# --> 278         self._compute_plot_data()
#     279         self._setup_subplots()
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     440         if is_empty:
# --> 441             raise TypeError("no numeric data to plot")
#     442
#
# TypeError: no numeric data to plot
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# C:\Users\SRHOPK~1\AppData\Local\Temp/ipykernel_24588/2349195176.py in <module>
#      20 # new_pumpkins.loc[new_pumpkins['Package'].str.contains('1/2'), 'Price'] = price/(1/2)
#      21
# ---> 22 new_pumpkins.groupby(['Color']).plot(kind='bar')
#      23 # plt.ylabel("Pumpkin Price")
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\groupby\groupby.py in __call__(self, *args, **kwargs)
#     464
#     465         f.__name__ = "plot"
# --> 466         return self._groupby.apply(f)
#     467
#     468     def __getattr__(self, name: str):
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     903
#     904                 with group_selection_context(self):
# --> 905                     return self._python_apply_general(f, self._selected_obj)
#     906
#     907         return result
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#     926             data after applying f
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#     930         return self._wrap_applied_output(
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     236             # group might be modified
#     237             group_axes = group.axes
# --> 238             res = f(group)
#     239             if not _is_indexed_like(res, group_axes, axis):
#     240                 mutated = True
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\groupby\groupby.py in f(self)
#     461     def __call__(self, *args, **kwargs):
#     462         def f(self):
# --> 463             return self.plot(*args, **kwargs)
#     464
#     465         f.__name__ = "plot"
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     276     def generate(self):
#     277         self._args_adjust()
# --> 278         self._compute_plot_data()
#     279         self._setup_subplots()
#     280         self._make_plot()
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     439         # no non-numeric frames or series allowed
#     440         if is_empty:
# --> 441             raise TypeError("no numeric data to plot")
#     442
#     443         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot
